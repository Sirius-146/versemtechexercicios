# %% [markdown]
# # Exercício 1:

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # Exercício 2:

# %%
num = input('Insira um número: ')
print(f'O número inserido foi: {num}')
# Out:
# Insira um número: 12
# O número inserido foi: 12

# %% [markdown]
# # Exercício 3:

# %%
num1 = int(input('Insira o primeiro número: '))
num2 = int(input('Insira o segundo número: '))

soma_valores = num1 + num2
print(f'A soma dos números é: {sum}')
# Out:
# Insira o primeiro número: 8
# Insira o segundo número: 17
# A soma dos números é: 25

# %% [markdown]
# # Exercício 4:

# %%
notas = []
counter = 4

while counter > 0:
  nota = int(input('Insira sua nota: '))
  notas.append(nota)
  counter -= 1

media = sum(notas) / len(notas)

print(f'A média é {media}')
# Out:
# Insira sua nota: 8
# Insira sua nota: 8
# Insira sua nota: 7
# Insira sua nota: 6
# A média é 7.25

# %% [markdown]
# #Exercício 5:

# %%
metro = float(input('Insira o valor em metros: '))
CM_POR_M = 100
centimetro = metro * CM_POR_M

print(f'O valor em centímetros é {int(centimetro)}')
# Out:
# Insira o valor em metros: 3.85
# O valor em centímetros é 385

# %% [markdown]
# # Exercício 6:

# %%
raio = float(input('Insira o raio do círculo: '))
PI = 3.1416

area = PI * raio**2

print(f'A área desse círculo é: {area}')
# Out:
# Insira o raio do círculo: 8
# A área desse círculo é: 201.0624

# %% [markdown]
# # Exercício 7:

# %%
lado = float(input('Insira a medida do lado do quadrado: '))

AREA = lado**2

print(AREA * 2)
# Out:
# Insira a medida do lado do quadrado: 163
# 53138.0

# %% [markdown]
# # Exercício 8:

# %%
salario_hora = float(input('Insira o salário por hora: '))
horas_mes = float(input('Insira a quantidade de horas trabaladas no mês: '))

salario_mensal = salario_hora * horas_mes

print(f'O sálario nesse mês é de: R${salario_mensal:.2f}')
# Out:
# Insira o salário por hora: 13
# Insira a quantidade de horas trabaladas no mês: 178
# O sálario nesse mês é de: R$2314.00

# %% [markdown]
# # Exercício 9:

# %%
temp_fahrenheit = float(input('Insira a temperatura em Fahrenheit: '))
temp_convert_celsius = 5 * ((temp_fahrenheit-32) / 9)

print(f'{temp_fahrenheit}°F convertidos para Celsius são {temp_convert_celsius}°C')
# Out:
# Insira a temperatura em Fahrenheit: 77
# 77.0°F convertidos para Celsius são 25.0°C

# %% [markdown]
# # Exercício 10:

# %%
temp_celsius = float(input('Insira a temperatura em Celsius: '))
temp_convert_fahrenheit = (temp_celsius / 5) * 9 + 32

print(f'{temp_celsius}°C convertidos para Fahrenheit são {temp_convert_fahrenheit}°F')
# Out:
# Insira a temperatura em Celsius: 27
# 27.0°C convertidos para Fahrenheit são 80.6°F

# %% [markdown]
# # Exercício 11:

# %%
numero1 = int(input('Insira um número inteiro: '))
numero2 = int(input('Insira outro número inteiro: '))
numero3 = float(input('Insira um número real: '))

a = (numero1 * 2) * (numero2 * 0.5)
b = (numero1 * 3) + (numero3)
c = numero3**3

print(f'A) produto do dobro do primeiro e metade do segundo: {a} \nB) soma do triplo do primeiro com o terceiro: {b} \nC) terceiro elevado ao cubo: {c}')
# Out:
# Insira um número inteiro: 12
# Insira outro número inteiro: 7
# Insira um número real: 3.1416
# A) produto do dobro do primeiro e metade do segundo: 84.0
# B) soma do triplo do primeiro com o terceiro: 39.1416
# C) terceiro elevado ao cubo: 31.006494199296

# %% [markdown]
# # Exercício 12:

# %%
altura = float(input('Insira sua altura: '))

peso_ideal = (72.7*altura) - 58

print(f'Seu peso ideal é {peso_ideal:.2f}Kg')
# Out:
# Insira sua altura: 1.81
# Seu peso ideal é 73.59Kg

# %% [markdown]
# # Exercício 13:

# %%
altura = float(input('Insira sua altura: '))

peso_ideal_homem = (72.7*altura) - 58
peso_ideal_mulher = (62.1*altura) - 44.7
print(f'Seu peso ideal é: \nCaso seja homem: {peso_ideal_homem:.2f}Kg \nCaso seja mulher: {peso_ideal_mulher:.2f}Kg')
# Out:
# Insira sua altura: 1.82
# Seu peso ideal é:
# Caso seja homem: 74.31Kg
# Caso seja mulher: 68.32Kg

# %% [markdown]
# # Exercício 14:

# %%
peso = float(input("Peso dos peixes: "))
LIMITE_PESO = 50
VALOR_MULTA = 4

excesso = peso - LIMITE_PESO
multa = excesso * VALOR_MULTA

print(f'Peso inserido {peso}Kg.\nSuperando o limite em {excesso}Kg, gerando uma multa de R${multa}')
# Out:
# Peso dos peixes: 63
# Peso inserido 63.0Kg.
#  Superando o limite em 13.0Kg, gerando uma multa de R$52.0

# %% [markdown]
# # Exercício 15:

# %%
sal_hora = float(input('Insira o salário por hora: '))
h_mes = float(input('Insira a quantidade de horas trabaladas no mês: '))

salario_bruto = sal_hora * h_mes
IMPOSTO_RENDA = salario_bruto * 0.11
INSS = salario_bruto * 0.08
SINDICATO =  salario_bruto * 0.05

salario_liquido = salario_bruto - IMPOSTO_RENDA - INSS - SINDICATO

print(f'''+ Salário Bruto : R${salario_bruto:.2f}
- IR (11%) : R${IMPOSTO_RENDA:.2f}
- INSS (8%) : R${INSS:.2f}
- Sindicato (5%) : R${SINDICATO:.2f}
= Salário Liquido : R${salario_liquido:.2f}''')
# Out:
# Insira o salário por hora: 14
# Insira a quantidade de horas trabaladas no mês: 180
# + Salário Bruto : R$2520.00
# - IR (11%) : R$277.20
# - INSS (8%) : R$201.60
# - Sindicato ( 5%) : R$126.00
# = Salário Liquido : R$1915.20

# %% [markdown]
# # Exercício 16:

# %%
area_pintura = float(input('Insira a área a ser pintada: '))

litro_por_metro = area_pintura / 3
tamanho_lata = 18
valor_lata = 80

qtd_lata = litro_por_metro // tamanho_lata + 1
valor_total = valor_lata * qtd_lata

print(f'Quantidade de latas: {int(qtd_lata)} \nValor a pagar R${valor_total}')
# Out:
# Insira a área a ser pintada: 187
# Quantidade de latas: 4
# Valor a pagar R$320.0

# %% [markdown]
# # Exercício 17:

# %%
area_pintar = float(input('Insira a área a ser pintada: '))

l_por_m = area_pintar / 6
lata_grande = 18
preco_lata_grande = 80
lata_pequena = 3.6
preco_lata_pequena = 25

qtd_de_lata = l_por_m // lata_grande + 1
total_lata_grande = preco_lata_grande * qtd_de_lata

qtd_de_latas = l_por_m // lata_pequena + 1
total_lata_pequena = preco_lata_pequena * qtd_de_latas

print(f'''Quantidade de latas grandes: {int(qtd_de_lata)} \nValor a pagar R${total_lata_grande}
Quantidade de latas pequenas: {int(qtd_de_latas)} \nValor a pagar R${total_lata_pequena}''')
# Out:
# Insira a área a ser pintada: 187
# Quantidade de latas grandes: 2
# Valor a pagar R$160.0
# Quantidade de latas pequenas: 9
# Valor a pagar R$225.0

# %% [markdown]
# # Exercício 18:

# %%
tamanho_arquivo = float(input('Insira o tamanho do arquivo (Mb): '))
velocidade_internet = float(input('Insira a velocidade da internet (Mbps): '))

velocidade_mbpm = velocidade_internet * 60
tempo = tamanho_arquivo / velocidade_mbpm

print(f'O download deve levar {tempo} minuto(s)')
# Out:
# Insira o tamanho do arquivo (Mb): 960
# Insira a velocidade da internet (Mbps): 5
# O download deve levar 3.2 minuto(s)
