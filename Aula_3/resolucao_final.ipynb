# %% [markdown]
# https://wiki.python.org.br/EstruturaDeDecisao

# %% [markdown]
# # Exercício 1:

# %% [markdown]
# Faça um Programa que peça dois números e imprima o maior deles.

# %%
num1 = int(input('Insira um número: '))
num2 = int(input('Insira um número: '))

maior = num1 > num2

if maior:
  print(f'O maior é {num1}')
else:
  print(f'O maior é {num2}')
# Out:
# Insira um número: 1
# Insira um número: 9
# O maior é 9

# %% [markdown]
# # Exercício 2:

# %% [markdown]
# Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
valor = int(input('Insira um número: '))

positivo = valor > 0

if positivo:
  print('O número é positivo')
else:
  print('O número é negativo')
# Out:
# Insira um número: -3
# O número é negativo

# %% [markdown]
# # Exercício 3:

# %% [markdown]
# Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

# %%
sex = input('Insira seu gênero:(M/F) ').upper()

masc = sex == 'M'
fem = sex == 'F'

if masc:
  print('M - Masculino')
elif fem:
  print('F - Feminino')
else:
  print('Sexo Inválido')
# Out:
# Insira seu gênero:(M/F) m
# M - Masculino

# %% [markdown]
# # Exercício 4:

# %% [markdown]
# Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = input('Insira uma letra: ').lower()

vogais = ['a', 'e', 'i', 'o', 'u']

vogal = letra in vogais

if vogal:
  print('A letra informada é vogal')
else:
  print('A letra informada é consoante')
# Out:
# Insira uma letra: I
# A letra informada é vogal

# %% [markdown]
# # Exercício 5:

# %% [markdown]
# Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# * A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# * A mensagem "Reprovado", se a média for menor do que sete;
# * A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota_1 = int(input('Insira sua nota: '))
nota_2 = int(input('Insira sua nota: '))

media = (nota_1 + nota_2) / 2

NOTA_MAXIMA = 10
MEDIA_APROVACAO = 7

super_aprovado = media == NOTA_MAXIMA
aprovado = media >= MEDIA_APROVACAO

if super_aprovado:
  print('Aprovado com Distinção')
elif aprovado:
  print('Aprovado')
else:
  print('Reprovado')
# Out:
# Insira sua nota: 8
# Insira sua nota: 5
# Reprovado

# %% [markdown]
# # Exercício 6:

# %% [markdown]
# Faça um Programa que leia três números e mostre o maior deles.

# %%
num1 = float(input('Insira um número: '))
num2 = float(input('Insira um número: '))
num3 = float(input('Insira um número: '))

num1_eh_maior = num1 > num2 and num1 > num3
num2_eh_maior = num2 > num3

if num1_eh_maior:
  print('O maior número é',num1)
elif num2_eh_maior:
  print('O maior número é',num2)
else:
  print('O maior número é',num3)
# Out:
# Insira um número: 2
# Insira um número: 5
# Insira um número: 7
# O maior número é 7.0

# %% [markdown]
# # Exercício 7:

# %% [markdown]
# Faça um Programa que leia três números e mostre o maior e o menor deles.

# %%
numeros = []
counter = 3

while counter > 0:
  num = float(input('Insira um número: '))
  numeros.append(num)
  counter -=1

print(f'O maior número é {max(numeros)}. \nO menor número é {min(numeros)}')
# Out:
# Insira um número: -3
# Insira um número: 2.54
# Insira um número: 17
# O maior número é 17.0.
# O menor número é -3.0

# %% [markdown]
# # Exercício 8:

# %% [markdown]
# Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
preco1 = float(input('Insira o preço do produto 1: '))
preco2 = float(input('Insira o preço do produto 2: '))
preco3 = float(input('Insira o preço do produto 3: '))

menor_preco1 = preco1 < preco2 and preco1 < preco3
menor_preco2 = preco2 < preco3

if menor_preco1:
  print('Compre o produto 1!')
elif menor_preco2:
  print('Compre o produto 2!')
else:
  print('Compre o produto 3!')
# Out:
# Insira o preço do produto 1: 1259.69
# Insira o preço do produto 2: 1259.68
# Insira o preço do produto 3: 1255.78
# Compre o produto 3!

# %% [markdown]
# # Exercício 9:

# %% [markdown]
# Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
n1 = int(input('Insira um número: '))
n2 = int(input('Insira um número: '))
n3 = int(input('Insira um número: '))

n1_maior = n1 > n2 and n1 > n3
n2_maior = n2 > n1 and n2 > n3
n3_maior = n3 > n2 and n3 > n1

ordem1 = n3_maior and n2 > n1
ordem2 = n3_maior and n1 > n2
ordem3 = n1_maior and n2 > n3
ordem4 = n1_maior and n3 > n2
ordem5 = n2_maior and n3 > n1
ordem6 = n2_maior and n1 > n3

if ordem1:
  print(n3, n2, n1)
elif ordem2:
  print(n3, n1, n2)
elif ordem3:
  print(n1, n2, n3)
elif ordem4:
  print(n1, n3, n2)
elif ordem5:
  print(n2, n3, n1)
else:
  print(n2, n1, n3)
# Out:
# Insira um número: 3
# Insira um número: 6
# Insira um número: 9
# 9 6 3

# %% [markdown]
# # Exercício 10:

# %% [markdown]
# Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
print('Qual seu turno? \nM - matutino \nV - vespertino \nN - noturno')
turno = input().upper()

matutino = turno == 'M'
vespertino = turno == 'V'
noturno = turno == 'N'

if matutino:
  print('Bom Dia!')
elif vespertino:
  print('Boa Tarde!')
elif noturno:
  print('Boa Noite!')
else:
  print('Valor Inválido!')
# Out:
# Qual seu turno?
# M - matutino
# V - vespertino
# N - noturno
# x
# Valor Inválido!

# %% [markdown]
# # Exercício 11:

# %% [markdown]
# As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contrataram para desenvolver o programa que calculará os reajustes.<br>
# Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
# * salários até R$ 280,00 (incluindo) : aumento de 20%
#
# * salários entre R$ 280,00 e 700,00 : aumento de 15%
#
# * salários entre R$ 700,00 e 1500,00 : aumento de 10%
#
# * salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
# * o salário antes do reajuste;
# * o percentual de aumento aplicado;
# * o valor do aumento;
# * o novo salário, após o aumento.

# %%
salario_atual = float(input('Salário atual: '))
novo_salario = None #Valor do novo salário
#valores atuais
valor = [280, 700, 1500]
#percentual de aumento
mais = [0.20, 0.15, 0.10, 0.05]
#conferência de valores
aumento20 = salario_atual <= valor[0]
aumento15 = salario_atual < valor[1]
aumento10 = salario_atual < valor[2]
aumento5 = salario_atual > valor[2]

if aumento20:
  percentual = mais[0]
  aumento = salario_atual * percentual
  novo_salario = salario_atual + aumento
elif aumento15:
  percentual = mais[1]
  aumento = salario_atual * percentual
  novo_salario = salario_atual + aumento
elif aumento10:
  percentual = mais[2]
  aumento = salario_atual * percentual
  novo_salario = salario_atual + aumento
else:
  percentual = mais[3]
  aumento = salario_atual * percentual
  novo_salario = salario_atual + aumento

print(f'Salário atual: {salario_atual} \nPercentual de aumento: {int(percentual * 100)}% \nValor de aumento: {aumento} \nSalário reajustado: {novo_salario}')
# Out:
# Salário atual: 1750
# Salário atual: 1750.0
# Percentual de aumento: 5%
# Valor de aumento: 87.5
# Salário reajustado: 1837.5

# %% [markdown]
# # Exercício 12:

# %% [markdown]
# Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.<br>
# Desconto do IR:
# * Salário Bruto até 900 (inclusive) - isento
# * Salário Bruto até 1500 (inclusive) - desconto de 5%
# * Salário Bruto até 2500 (inclusive) - desconto de 10%
# * Salário Bruto acima de 2500 - desconto de 20% <br>
# Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.
#         Salário Bruto: (5 * 220)        : R$ 1100,00
#         (-) IR (5%)                     : R$   55,00
#         (-) INSS ( 10%)                 : R$  110,00
#         FGTS (11%)                      : R$  121,00
#         Total de descontos              : R$  165,00
#         Salário Liquido                 : R$  935,00

# %%
#calculando a hora trabalhada e valor da hora trabalhada
valor_hora_str = input('Insira o valor da sua hora trabalhada: ')
valor_hora_str = valor_hora_str.replace(',', '.')
valor_hora = float(valor_hora_str)

total_horas_str = input('Insira o total de horas trabalhadas: ')
total_horas_str = total_horas_str.replace(',', '.')
total_horas = float(total_horas_str)

salary = valor_hora * total_horas #Calcula o salário
salario_final = None #armazena o valor líquido do salário

valor_base = [900, 1500, 2500] #Salários base para incidencia das taxas de IR

INSS = 0.1 #desconto INSS (Obs: tá errado, o valor varia de acordo com o salário)
FGTS = 0.11 #valor a ser pago de FGTS
IR = [0.05, 0.10, 0.20] #porcentagem de desconto de IR, de acordo com o salário

#Testa a faixa de salário
salary_1 = salary <= valor_base[0]
salary_2 = salary <= valor_base[1]
salary_3 = salary <= valor_base[2]

#Calcula os descontos fixos
inss_desconto = salary * INSS
fgts_desconto = salary * FGTS

if salary_1:
  desconto = 0
  salario_final = 0
elif salary_2:
  desconto = IR[0]
  salario_final = salary * desconto
elif salary_3:
  desconto = IR[1]
  salario_final = salary * desconto
else:
  desconto = IR[2]
  salario_final = salary * desconto

print(f'''  Salário Bruto:             : R$ {salary:.2f}
  (-) IR ({(desconto*100):.0f}%)               : R$ {salario_final:.2f}
  (-) INSS (10%)             : R$ {inss_desconto:.2f}
  FGTS (11%)                 : R$ {fgts_desconto:.2f}
  Total de descontos         : R$ {(salario_final + inss_desconto):.2f}
  Salário Liquido            : R$ {salary - (salario_final + inss_desconto):.2f}
''')
# Out:
# Insira o valor da sua hora trabalhada: 19,7
# Insira o total de horas trabalhadas: 145
#   Salário Bruto:             : R$ 2856.50
#   (-) IR (20%)               : R$ 571.30
#   (-) INSS (10%)             : R$ 285.65
#   FGTS (11%)                 : R$ 314.21
#   Total de descontos         : R$ 856.95
#   Salário Liquido            : R$ 1999.55

# %% [markdown]
# # Exercício 13:

# %% [markdown]
# Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
dia_num = int(input('Número do dia: '))

dias = {
    1: "Domingo", 2: "Segunda", 3: "Terça", 4: "Quarta", 5: "Quinta", 6: "Sexta", 7: "Sábado"
}

print(dias.get(dia_num, "Valor Inválido"))
# Out:
# Número do dia: 7
# Sábado

# %% [markdown]
# # Exercício 14:

# %% [markdown]
# Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:
# >
#     Média de Aproveitamento  Conceito
#     Entre 9.0 e 10.0        A
#     Entre 7.5 e 9.0         B
#     Entre 6.0 e 7.5         C
#     Entre 4.0 e 6.0         D
#     Entre 4.0 e zero        E
# O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o conceito for A, B ou C ou “REPROVADO” se o conceito for D ou E.

# %%
nota1 = float(input('Insira sua nota: '))
nota2 = float(input('Insira sua nota: '))

AVG = (nota1 + nota2) / 2

nota_A = AVG >= 9
nota_B = AVG >= 7.5
nota_C = AVG >= 6
nota_D = AVG >= 4

#APROVADO = nota_A or nota_B or nota_C

print(f'Nota 1: {nota1} \nNota 2: {nota2} \nMédia: {AVG}')

if nota_A:
  print('Conceito: A \nAprovado!')
elif nota_B:
  print('Conceito: B \nAprovado!')
elif nota_C:
  print('Conceito: C \nAprovado!')
elif nota_D:
  print('Conceito: D \nReprovado!')
else:
  print('Conceito: E \nReprovado!')
# Out:
# Insira sua nota: 8
# Insira sua nota: 9
# Nota 1: 8.0
# Nota 2: 9.0
# Média: 8.5
# Conceito: B
# Aprovado!

# %% [markdown]
# # Exercício 15:

# %% [markdown]
# Faça um Programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.<br>
# >Dicas:
# * Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# * Triângulo Equilátero: três lados iguais;
# * Triângulo Isósceles: quaisquer dois lados iguais;
# * Triângulo Escaleno: três lados diferentes;

# %%
lado1 = int(input('Insira o valor dos lado: '))
lado2 = int(input('Insira o valor dos lado: '))
lado3 = int(input('Insira o valor dos lado: '))

triangulo_valido = (lado1 + lado2) > lado3 and (lado1 + lado3) > lado2 and (lado3 + lado2) > lado1

equilatero = lado1 == lado2 and lado2 == lado3 and lado3 == lado1
isosceles = lado1 == lado2 or lado2 == lado3 or lado3 == lado1

if triangulo_valido:
  print("Esse triângulo é válido")
  if equilatero:
    print('Esse é um triângulo equilátero!')
  elif isosceles:
    print('Esse é um triângulo isósceles!')
  else:
    print('Esse é um triângulo escaleno!')
else:
  print("Esse triângulo não é válido")
# Out:
# Insira o valor dos lado: 6
# Insira o valor dos lado: 6
# Insira o valor dos lado: 6
# Esse triângulo é válido
# Esse é um triângulo equilátero!

# %% [markdown]
# # Exercício 16:

# %% [markdown]
# Faça um programa que calcule as raízes de uma equação do segundo grau, na forma ax2 + bx + c. O programa deverá pedir os valores de a, b e c e fazer as consistências, informando ao usuário nas seguintes situações:
# 1. Se o usuário informar o valor de A igual a zero, a equação não é do segundo grau e o programa não deve fazer pedir os demais valores, sendo encerrado;
# 2. Se o delta calculado for negativo, a equação não possui raizes reais. Informe ao usuário e encerre o programa;
# 3. Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe-a ao usuário;
# 4. Se o delta for positivo, a equação possui duas raiz reais; informe-as ao usuário;

# %%
a_valor = int(input('Insira o valor: '))
no_valid = a_valor == 0
if no_valid:
  print('Equação não é do segundo grau')
else:
  b_valor = int(input('Insira o valor: '))
  c_valor = int(input('Insira o valor: '))

BHASKARA = b_valor**2 - (4 * a_valor * c_valor)
raiz1 = (-(b_valor) + BHASKARA**0.5) / (2*a_valor)
raiz2 = (-(b_valor) - BHASKARA**0.5) / (2*a_valor)

no_raizes_reais = BHASKARA < 0
uma_raiz_real = BHASKARA == 0

if no_raizes_reais:
  print('A expressão não posssui raízes reais')
elif uma_raiz_real:
  print(f'A expressão posssui uma raíz real: {raiz1}')
else:
  print(f'Os valores das raízes são: {int(raiz1)} e {int(raiz2)}')
# Out:
# Insira o valor: 1
# Insira o valor: -3
# Insira o valor: -54
# Os valores das raízes são: 9 e -6

# %% [markdown]
# # Exercício 17:

# %% [markdown]
# Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.

# %%
year = int(input('Insira o ano: '))

rule1 = year % 4 == 0 and year % 100 != 0
rule2 = year % 400 == 0

eh_bissexto = rule1 or rule2

if eh_bissexto:
  print(f'O ano {year} é bissexto')
else:
  print(f'O ano {year} não é bissexto')
# Out:
# Insira o ano: 1996
# O ano 1996 é bissexto

# %% [markdown]
# # Exercício 18:

# %% [markdown]
# Faça um Programa que peça uma data no formato dd/mm/aaaa e determine se a mesma é uma data válida.

# %%
from datetime import datetime

data_atual = input('Insira uma data: (dd/mm/aaaa) ')

try:
  texto_em_data = datetime.strptime(data_atual, '%d/%m/%Y')
  print('Essa data é válida')
except:
  print('Essa não é uma data real')
# Out:
# Insira uma data: (dd/mm/aaaa) 19/03/1885
# Essa data é válida

# %%
data_atual = input('Insira uma data: (dd/mm/aaaa) ')

nova = data_atual.split('/')

print(nova)
# Out:
# Insira uma data: (dd/mm/aaaa) 22/02/2002
# ['22', '02', '2002']

# %% [markdown]
# # Exercício 19:

# %% [markdown]
# Faça um Programa que leia um número inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo.
# > Observando os termos no plural a colocação do "e", da vírgula entre outros. Exemplo:
# * 326 = 3 centenas, 2 dezenas e 6 unidades
# * 12 = 1 dezena e 2 unidades
# <br>Testar com: 326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7 e 16

# %%
# numeros_teste = [326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7, 16]

nummer = input()

for i in nummer:
  print(i)
# Out:
# 245
# 2
# 4
# 5
